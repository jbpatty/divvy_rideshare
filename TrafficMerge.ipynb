# %% [markdown]
# # Loading, Cleaning, and Merging Divvy Data

# %% [markdown]
# ### Loading Code To Pull Data From Google Cloud Platform

# %%
# Code to read csv file into Colaboratory:
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
from google.colab import  drive
drive.mount('/drive')
import pandas as pd
# Out:
# Mounted at /drive

# %%
# Authenticate and create the PyDrive client.
auth.authenticate_user('jbpatty01@gmail.com')
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %% [markdown]
# ### 2013-2018 Chicago Traffic Congestion Records Dataset

# %%
# 2013-2018

link = 'https://drive.google.com/file/d/1z4R0C5ggLHjB03pVaUmIq5Zgc1SpptCE/view?usp=sharing' # The shareable link

fluff, id = link.split('d/')
id = id[0:33]
print (id) # Verify that you have everything after 'd/'

downloaded = drive.CreateFile({'id':id}) 
downloaded.GetContentFile('Filename.csv')  
congestion_by_region = pd.read_csv('Filename.csv')
# Dataset is now stored in a Pandas Dataframe
# Out:
# 1z4R0C5ggLHjB03pVaUmIq5Zgc1SpptCE

# %%
congestion_by_region = congestion_by_region.rename(columns={"TIME":"time", "REGION_ID":"region_id", "BUS COUNT":"bus_count", "NUMBER OF READS                      ":"number_of_reads", "SPEED":"speed"})

# %%
congestion_by_region['time'] = pd.to_datetime(congestion_by_region['time'], format = '%m/%d/%Y  %I:%M:%S %p')

# %%
congestion_by_region = congestion_by_region.sort_values(by='time')

# %%
congestion_by_region.sample(10)
# Out:
#                        time  region_id  bus_count  number_of_reads  speed
# 767172  2014-08-30 23:50:26          7         44              629  21.27
# 979270  2014-07-10 23:50:26         28          8              162  42.89
# 1946993 2013-11-14 23:50:26         21         70             1018  21.14
# 4574921 2017-05-30 13:10:44         16         45              686  23.86
# 2439557 2013-07-17 23:50:26         20         27              411  27.95
# 2224852 2013-09-08 23:50:26          2          4               25   0.00
# 3118595 2013-02-01 23:50:26         12         62              844  15.68
# 235144  2015-01-06 23:50:26         13        146             2342  12.95
# 2407490 2013-07-24 23:50:26         28          9              155  41.05
# 5931092 2016-07-03 23:10:31         13         37              527  21.82

# %% [markdown]
# ### Chicago Traffic Congestion Regions Dataset

# %%
# Region IDs

link4 = 'https://drive.google.com/file/d/1fGEaa6-g3nde8mWNHNs5orjf-Uv5bMt9/view?usp=sharing' # The shareable link

fluff4, id4 = link4.split('d/')
id4 = id4[0:33]
print (id4) # Verify that you have everything after 'd/'

downloaded4 = drive.CreateFile({'id':id4}) 
downloaded4.GetContentFile('Filename.csv')  
congestion_by_region4 = pd.read_csv('Filename.csv')
# Dataset is now stored in a Pandas Dataframe
# Out:
# 1fGEaa6-g3nde8mWNHNs5orjf-Uv5bMt9

# %%
congestion_by_region4
# Out:
#                                REGION  ...           LAST_UPDATED
# 0                        Chicago Loop  ...  2020-11-30 15:40:55.0
# 1                        Lawndale N/S  ...  2020-11-30 15:40:55.0
# 2                      Far North West  ...  2020-11-30 15:40:55.0
# 3                Hermosa-Logan Square  ...  2020-11-30 15:40:55.0
# 4                          Near North  ...  2020-11-30 15:40:55.0
# 5                  Near South-Douglas  ...  2020-11-30 15:40:55.0
# 6         South Shore-S Chicago-Avlon  ...  2020-11-30 15:40:55.0
# 7       Dunning-Portage-Belmont Cragn  ...  2020-11-30 15:40:55.0
# 8                 Riverdale-Hegewisch  ...  2020-11-30 15:40:55.0
# 9             South Deering-East Side  ...  2020-11-30 15:40:55.0
# 10                    South West Side  ...  2020-11-30 15:40:55.0
# 11                West Town-Near West  ...  2020-11-30 15:40:55.0
# 12  Fuller-Grand Blvd-Washington Park  ...  2020-11-30 15:40:55.0
# ...
