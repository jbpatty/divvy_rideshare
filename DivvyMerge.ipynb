# %% [markdown]
# # Loading, Cleaning, and Merging Divvy Data

# %% [markdown]
# ### Loading Code To Pull Data From Google Cloud Platform

# %%
# Code to read csv file into Colaboratory:
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
from google.colab import  drive
drive.mount('/drive')
import pandas as pd
# Out:
# Mounted at /drive

# %%
# Authenticate and create the PyDrive client.
auth.authenticate_user('jbpatty01@gmail.com')
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %% [markdown]
# ### 2018 Divvy Rideshare Datasets

# %%
# 2018 Q4

link6 = 'https://drive.google.com/file/d/1BjxE2Y43yN9yyXyTXWtK1EBWscE107lB/view?usp=sharing' # The shareable link

fluff6, id6 = link6.split('d/')
id6 = id6[0:33]
print (id6) # Verify that you have everything after 'd/'

downloaded6 = drive.CreateFile({'id':id6}) 
downloaded6.GetContentFile('Filename.csv')  
divvy_trips_2018_q4 = pd.read_csv('Filename.csv')
# Dataset is now stored in a Pandas Dataframe
# Out:
# 1BjxE2Y43yN9yyXyTXWtK1EBWscE107lB

# %%
# 2018 Q3

link7 = 'https://drive.google.com/file/d/1npUZ2CNIytVuJ-ePP0Bd3a0mKlrJdFRq/view?usp=sharing' # The shareable link

fluff7, id7 = link7.split('d/')
id7 = id7[0:33]
print (id7) # Verify that you have everything after 'd/'

downloaded7 = drive.CreateFile({'id':id7}) 
downloaded7.GetContentFile('Filename.csv')  
divvy_trips_2018_q3 = pd.read_csv('Filename.csv')
# Dataset is now stored in a Pandas Dataframe
# Out:
# 1npUZ2CNIytVuJ-ePP0Bd3a0mKlrJdFRq

# %%
# 2018 Q2

link8 = 'https://drive.google.com/file/d/1_Vu-uIyAsQjPQyAXU-KqDjaRGNnjguTn/view?usp=sharing' # The shareable link

fluff8, id8 = link8.split('d/')
id8 = id8[0:33]
print (id8) # Verify that you have everything after 'd/'

downloaded8 = drive.CreateFile({'id':id8}) 
downloaded8.GetContentFile('Filename.csv')  
divvy_trips_2018_q2 = pd.read_csv('Filename.csv')
# Dataset is now stored in a Pandas Dataframe
# Out:
# 1_Vu-uIyAsQjPQyAXU-KqDjaRGNnjguTn

# %%
# 2018 Q1

link9 = 'https://drive.google.com/file/d/1mVi93DHVfxeNkhaZRdHgiGcxPsXUg73S/view?usp=sharing' # The shareable link

fluff9, id9 = link9.split('d/')
id9 = id9[0:33]
print (id9) # Verify that you have everything after 'd/'

downloaded9 = drive.CreateFile({'id':id9}) 
downloaded9.GetContentFile('Filename.csv')  
divvy_trips_2018_q1 = pd.read_csv('Filename.csv')
# Dataset is now stored in a Pandas Dataframe
# Out:
# 1mVi93DHVfxeNkhaZRdHgiGcxPsXUg73S

# %%
# Rename 2018 Q1 to match the other quarters 

divvy_trips_2018_q1 = divvy_trips_2018_q1.rename(columns = {'01 - Rental Details Rental ID':'trip_id', 
                                                                  '01 - Rental Details Local Start Time':'start_time', 
                                                                  '01 - Rental Details Local End Time':'end_time', 
                                                                  '01 - Rental Details Bike ID':'bikeid', 
                                                                  '01 - Rental Details Duration In Seconds Uncapped':'tripduration',
                                                                  '03 - Rental Start Station ID':'from_station_id', 
                                                                  '03 - Rental Start Station Name':'from_station_name', 
                                                                  '02 - Rental End Station ID':'to_station_id',
                                                                  '02 - Rental End Station Name':'to_station_name', 
                                                                  'User Type':'usertype', 
                                                                  'Member Gender':'gender', 
                                                                  '05 - Member Details Member Birthday Year':'birthyear'})

# %%
divvy_2018 = [divvy_trips_2018_q4,divvy_trips_2018_q3,divvy_trips_2018_q2,divvy_trips_2018_q1]

# %%
divvy_trips_2018 = pd.concat(divvy_2018, axis=0)

# %%
divvy_trips_2018 = divvy_trips_2018.sort_values(by='start_time')

# %%
divvy_trips_2018['start_time'] = pd.to_datetime(divvy_trips_2018['start_time'], format = '%Y-%m-%d  %H:%M:%S')
divvy_trips_2018['end_time'] = pd.to_datetime(divvy_trips_2018['end_time'], format = '%Y-%m-%d  %H:%M:%S')
divvy_trips_2018['tripduration'] = divvy_trips_2018['tripduration'].str.replace(',','')
divvy_trips_2018['tripduration'] = divvy_trips_2018['tripduration'].astype(float)

# %% [markdown]
# ### 2017 Divvy Rideshare Datasets

# %%
# 2017 Q4

link10 = 'https://drive.google.com/file/d/1mIiD0J2XYgSRb1O8zJc6Y_9H1M3f_2Xe/view?usp=sharing' # The shareable link

fluff10, id10 = link10.split('d/')
id10 = id10[0:33]
print (id10) # Verify that you have everything after 'd/'

downloaded10 = drive.CreateFile({'id':id10}) 
downloaded10.GetContentFile('Filename.csv')  
divvy_trips_2017_q4 = pd.read_csv('Filename.csv')
# Dataset is now stored in a Pandas Dataframe
# Out:
# 1mIiD0J2XYgSRb1O8zJc6Y_9H1M3f_2Xe

# %%
# 2017 Q3

link11 = 'https://drive.google.com/file/d/1aMWSHn_Tz1vt36O4Yo2vU_AOx_UOMtem/view?usp=sharing' # The shareable link

fluff11, id11 = link11.split('d/')
id11 = id11[0:33]
print (id11) # Verify that you have everything after 'd/'

downloaded11 = drive.CreateFile({'id':id11}) 
downloaded11.GetContentFile('Filename.csv')  
divvy_trips_2017_q3 = pd.read_csv('Filename.csv')
# Dataset is now stored in a Pandas Dataframe
# Out:
# 1aMWSHn_Tz1vt36O4Yo2vU_AOx_UOMtem

# %%
# 2017 Q2

link12 = 'https://drive.google.com/file/d/1jOk8EqdlxUNMREg0jSCXCcOXjq3q-lzB/view?usp=sharing' # The shareable link

fluff12, id12 = link12.split('d/')
id12 = id12[0:33]
print (id12) # Verify that you have everything after 'd/'

downloaded12 = drive.CreateFile({'id':id12}) 
downloaded12.GetContentFile('Filename.csv')  
divvy_trips_2017_q2 = pd.read_csv('Filename.csv')
# Dataset is now stored in a Pandas Dataframe
# Out:
# 1jOk8EqdlxUNMREg0jSCXCcOXjq3q-lzB

# %%
# 2017 Q1

link13 = 'https://drive.google.com/file/d/1hjnxqCKyKaOqlKtZzFMDWwNX-c-r22cZ/view?usp=sharing' # The shareable link

fluff13, id13 = link13.split('d/')
id13 = id13[0:33]
print (id13) # Verify that you have everything after 'd/'

downloaded13 = drive.CreateFile({'id':id13}) 
downloaded13.GetContentFile('Filename.csv')  
divvy_trips_2017_q1 = pd.read_csv('Filename.csv')
# Dataset is now stored in a Pandas Dataframe
# Out:
# 1hjnxqCKyKaOqlKtZzFMDWwNX-c-r22cZ

# %%
divvy_2017 = [divvy_trips_2017_q4,divvy_trips_2017_q3,divvy_trips_2017_q2,divvy_trips_2017_q1]

# %%
divvy_trips_2017 = pd.concat(divvy_2017, axis=0)

# %%
divvy_trips_2017 = divvy_trips_2017.sort_values(by='start_time')

# %%
divvy_trips_2017['start_time'] = divvy_trips_2017['start_time'].apply(lambda x: x+':00' if len(x) <= 16 else x)
divvy_trips_2017['end_time'] = divvy_trips_2017['end_time'].apply(lambda x: x+':00' if len(x) <= 16 else x)

# %%
divvy_trips_2017['start_time'] = pd.to_datetime(divvy_trips_2017['start_time'], format = '%m/%d/%Y %H:%M:%S')
divvy_trips_2017['end_time'] = pd.to_datetime(divvy_trips_2017['end_time'], format = '%m/%d/%Y %H:%M:%S')

# %% [markdown]
# ### 2016 Divvy Rideshare Datasets

# %%
# 2016 Q4

link14 = 'https://drive.google.com/file/d/1wSp449zyoHFSWt8El9i5kyO_hoZsDi1x/view?usp=sharing' # The shareable link

fluff14, id14 = link14.split('d/')
id14 = id14[0:33]
print (id14) # Verify that you have everything after 'd/'

downloaded14 = drive.CreateFile({'id':id14}) 
downloaded14.GetContentFile('Filename.csv')  
divvy_trips_2016_q4 = pd.read_csv('Filename.csv')
# Dataset is now stored in a Pandas Dataframe
# Out:
# 1wSp449zyoHFSWt8El9i5kyO_hoZsDi1x

# %%
# 2016 Q3

link15 = 'https://drive.google.com/file/d/1hqsiky8A_MbtRg2ZmNB3a9Ju2_TnYbW5/view?usp=sharing' # The shareable link

fluff15, id15 = link15.split('d/')
id15 = id15[0:33]
print (id15) # Verify that you have everything after 'd/'

downloaded15 = drive.CreateFile({'id':id15}) 
downloaded15.GetContentFile('Filename.csv')  
divvy_trips_2016_q3 = pd.read_csv('Filename.csv')
# Dataset is now stored in a Pandas Dataframe
# Out:
# 1hqsiky8A_MbtRg2ZmNB3a9Ju2_TnYbW5

# %%
# 2016 Q2 - June/06

link16 = 'https://drive.google.com/file/d/1XeJAXPVQk93_qSyKZh6XOwja_udyLtfm/view?usp=sharing' # The shareable link

fluff16, id16 = link16.split('d/')
id16 = id16[0:33]
print (id16) # Verify that you have everything after 'd/'

downloaded16 = drive.CreateFile({'id':id16}) 
downloaded16.GetContentFile('Filename.csv')  
divvy_trips_2016_06 = pd.read_csv('Filename.csv')
# Dataset is now stored in a Pandas Dataframe
# Out:
# 1XeJAXPVQk93_qSyKZh6XOwja_udyLtfm

# %%
# 2016 Q2 - May/05

link17 = 'https://drive.google.com/file/d/1UU0XTQxcFV7OgnJ93_312T8HbiPDkZww/view?usp=sharing' # The shareable link

fluff17, id17 = link17.split('d/')
id17 = id17[0:33]
print (id17) # Verify that you have everything after 'd/'

downloaded17 = drive.CreateFile({'id':id17}) 
downloaded17.GetContentFile('Filename.csv')  
divvy_trips_2016_05 = pd.read_csv('Filename.csv')
# Dataset is now stored in a Pandas Dataframe
# Out:
# 1UU0XTQxcFV7OgnJ93_312T8HbiPDkZww

# %%
# 2016 Q2 - April/04

link18 = 'https://drive.google.com/file/d/1FuZN411TWaNxzWB6Ctt1qtJvK0VGbxbC/view?usp=sharing' # The shareable link

fluff18, id18 = link18.split('d/')
id18 = id18[0:33]
print (id18) # Verify that you have everything after 'd/'

downloaded18 = drive.CreateFile({'id':id18}) 
downloaded18.GetContentFile('Filename.csv')  
divvy_trips_2016_04 = pd.read_csv('Filename.csv')
# Dataset is now stored in a Pandas Dataframe
# Out:
# 1FuZN411TWaNxzWB6Ctt1qtJvK0VGbxbC

# %%
# 2016 Q1

link19 = 'https://drive.google.com/file/d/1yz43UJWE1eL7bd7_XJFtWftXECZcBwA-/view?usp=sharing' # The shareable link

fluff19, id19 = link19.split('d/')
id19 = id19[0:33]
print (id19) # Verify that you have everything after 'd/'

downloaded19 = drive.CreateFile({'id':id19}) 
downloaded19.GetContentFile('Filename.csv')  
divvy_trips_2016_q1 = pd.read_csv('Filename.csv')
# Dataset is now stored in a Pandas Dataframe
# Out:
# 1yz43UJWE1eL7bd7_XJFtWftXECZcBwA-

# %%
divvy_2016 = [divvy_trips_2016_q4,divvy_trips_2016_q3,divvy_trips_2016_06,divvy_trips_2016_05,divvy_trips_2016_04,divvy_trips_2016_q1]

# %%
divvy_trips_2016 = pd.concat(divvy_2016, axis=0)

# %%
# Rename 2016 columns to match future years
divvy_trips_2016 = divvy_trips_2016.rename(columns = {'starttime':'start_time','stoptime':'end_time'})

# %%
divvy_trips_2016 = divvy_trips_2016.sort_values(by='start_time')

# %%
divvy_trips_2016['start_time'] = divvy_trips_2016['start_time'].apply(lambda x: x+':00' if len(x) <= 16 else x)
divvy_trips_2016['end_time'] = divvy_trips_2016['end_time'].apply(lambda x: x+':00' if len(x) <= 15 else x)

# %%
divvy_trips_2016['start_time'] = pd.to_datetime(divvy_trips_2016['start_time'], format = '%m/%d/%Y  %H:%M:%S')
divvy_trips_2016['end_time'] = pd.to_datetime(divvy_trips_2016['end_time'], format = '%m/%d/%Y  %H:%M:%S')

# %% [markdown]
# ### 2015 Divvy Rideshare Datasets

# %%
# 2015 Q4

link20 = 'https://drive.google.com/file/d/1_3PCC04P5Sz5W_WQ4o9j103RMZMhv0oj/view?usp=sharing' # The shareable link

fluff20, id20 = link20.split('d/')
id20 = id20[0:33]
print (id20) # Verify that you have everything after 'd/'

downloaded20 = drive.CreateFile({'id':id20}) 
downloaded20.GetContentFile('Filename.csv')  
divvy_trips_2015_q4 = pd.read_csv('Filename.csv')
# Dataset is now stored in a Pandas Dataframe
# Out:
# 1_3PCC04P5Sz5W_WQ4o9j103RMZMhv0oj

# %%
# 2015 Q3 - September/09

link21 = 'https://drive.google.com/file/d/1L0mU13O4VRsnFEWN97ziYM7XTU-E4n9Z/view?usp=sharing' # The shareable link

fluff21, id21 = link21.split('d/')
id21 = id21[0:33]
print (id21) # Verify that you have everything after 'd/'

downloaded21 = drive.CreateFile({'id':id21}) 
downloaded21.GetContentFile('Filename.csv')  
divvy_trips_2015_09 = pd.read_csv('Filename.csv')
# Dataset is now stored in a Pandas Dataframe
# Out:
# 1L0mU13O4VRsnFEWN97ziYM7XTU-E4n9Z

# %%
# 2015 Q3 - August/08

link22 = 'https://drive.google.com/file/d/1QbG9EFIpBMnxvm9KDlopNuFPsf4V5PzM/view?usp=sharing' # The shareable link

fluff22, id22 = link22.split('d/')
id22 = id22[0:33]
print (id22)# Verify that you have everything after 'd/'

downloaded22 = drive.CreateFile({'id':id22}) 
downloaded22.GetContentFile('Filename.csv')  
divvy_trips_2015_08 = pd.read_csv('Filename.csv')
# Dataset is now stored in a Pandas Dataframe
# Out:
# 1QbG9EFIpBMnxvm9KDlopNuFPsf4V5PzM

# %%
# 2015 Q3 - July/07

link23 = 'https://drive.google.com/file/d/12cEfnYLAEpKcuVOR1rcP-kblv5ovuWaY/view?usp=sharing' # The shareable link

fluff23, id23 = link23.split('d/')
id23 = id23[0:33]
print (id23) # Verify that you have everything after 'd/'

downloaded23 = drive.CreateFile({'id':id23}) 
downloaded23.GetContentFile('Filename.csv')  
divvy_trips_2015_07 = pd.read_csv('Filename.csv')
# Dataset is now stored in a Pandas Dataframe
# Out:
# 12cEfnYLAEpKcuVOR1rcP-kblv5ovuWaY

# %%
# 2015 Q2

link24 = 'https://drive.google.com/file/d/1MShUETMwT83WQ1QTQiO3M3rYa_xEPCdr/view?usp=sharing' # The shareable link

fluff24, id24 = link24.split('d/')
id24 = id24[0:33]
print (id24) # Verify that you have everything after 'd/'

downloaded24 = drive.CreateFile({'id':id24}) 
downloaded24.GetContentFile('Filename.csv')  
divvy_trips_2015_q2 = pd.read_csv('Filename.csv')
# Dataset is now stored in a Pandas Dataframe
# Out:
# 1MShUETMwT83WQ1QTQiO3M3rYa_xEPCdr

# %%
# 2015 Q1

link25 = 'https://drive.google.com/file/d/1OIGqc_rknh9OBwf-raDxv5u-kE0krmDR/view?usp=sharing' # The shareable link

fluff25, id25 = link25.split('d/')
id25 = id25[0:33]
print (id25) # Verify that you have everything after 'd/'

downloaded25 = drive.CreateFile({'id':id25}) 
downloaded25.GetContentFile('Filename.csv')  
divvy_trips_2015_q1 = pd.read_csv('Filename.csv')
# Dataset is now stored in a Pandas Dataframe
# Out:
# 1OIGqc_rknh9OBwf-raDxv5u-kE0krmDR

# %%
divvy_2015 = [divvy_trips_2015_q4,divvy_trips_2015_09,divvy_trips_2015_08,divvy_trips_2015_07,divvy_trips_2015_q2,divvy_trips_2015_q1]

# %%
divvy_trips_2015 = pd.concat(divvy_2015, axis=0)

# %%
# Rename 2015 columns to match future years
divvy_trips_2015 = divvy_trips_2015.rename(columns = {'starttime':'start_time','stoptime':'end_time'})

# %%
divvy_trips_2015 = divvy_trips_2015.sort_values(by='start_time')

# %%
divvy_trips_2015['start_time'] = divvy_trips_2015['start_time'].apply(lambda x: x+':00' if len(x) <= 16 else x)
divvy_trips_2015['end_time'] = divvy_trips_2015['end_time'].apply(lambda x: x+':00' if len(x) <= 16 else x)

# %%
divvy_trips_2015['start_time'] = pd.to_datetime(divvy_trips_2015['start_time'], format = '%m/%d/%Y  %H:%M:%S')
divvy_trips_2015['end_time'] = pd.to_datetime(divvy_trips_2015['end_time'], format = '%m/%d/%Y  %H:%M:%S')

# %% [markdown]
# ### 2014 Divvy Rideshare Datasets

# %%
# 2014 Q4

link26 = 'https://drive.google.com/file/d/1OIGqc_rknh9OBwf-raDxv5u-kE0krmDR/view?usp=sharing' # The shareable link

fluff26, id26 = link26.split('d/')
id26 = id26[0:33]
print (id26) # Verify that you have everything after 'd/'

downloaded26 = drive.CreateFile({'id':id26}) 
downloaded26.GetContentFile('Filename.csv')  
divvy_trips_2014_q4 = pd.read_csv('Filename.csv')
# Dataset is now stored in a Pandas Dataframe
# Out:
# 1OIGqc_rknh9OBwf-raDxv5u-kE0krmDR

# %%
# 2014 Q4

link26 = 'https://drive.google.com/file/d/1y3FqJ2sh-pESaGqv5Z9X77lpW7QdXJTn/view?usp=sharing' # The shareable link

fluff26, id26 = link26.split('d/')
id26 = id26[0:33]
print (id26) # Verify that you have everything after 'd/'

downloaded26 = drive.CreateFile({'id':id26}) 
downloaded26.GetContentFile('Filename.csv')  
divvy_trips_2014_q4 = pd.read_csv('Filename.csv')
# Dataset is now stored in a Pandas Dataframe
# Out:
# 1y3FqJ2sh-pESaGqv5Z9X77lpW7QdXJTn

# %%
# 2014 Q3 - August/September 08/09

link27 = 'https://drive.google.com/file/d/1kB4oO973ZaIXs6mya37XYMrvumdWWTz6/view?usp=sharing' # The shareable link

fluff27, id27 = link27.split('d/')
id27 = id27[0:33]
print (id27) # Verify that you have everything after 'd/'

downloaded27 = drive.CreateFile({'id':id27}) 
downloaded27.GetContentFile('Filename.csv')  
divvy_trips_2014_0809 = pd.read_csv('Filename.csv')
# Dataset is now stored in a Pandas Dataframe
# Out:
# 1kB4oO973ZaIXs6mya37XYMrvumdWWTz6

# %%
# 2014 Q3 - July/07

link28 = 'https://drive.google.com/file/d/1dStpHbum7M7mWjnymNqx0KdOBIdE5YTo/view?usp=sharing' # The shareable link

fluff28, id28 = link28.split('d/')
id28 = id28[0:33]
print (id28) # Verify that you have everything after 'd/'

downloaded28 = drive.CreateFile({'id':id28}) 
downloaded28.GetContentFile('Filename.csv')  
divvy_trips_2014_07 = pd.read_csv('Filename.csv')
# Dataset is now stored in a Pandas Dataframe
# Out:
# 1dStpHbum7M7mWjnymNqx0KdOBIdE5YTo

# %%
# 2014 Q2/Q1 

link29 = 'https://drive.google.com/file/d/1SncXLKgidPPN_f4RYnpnd5e2zujbnOI5/view?usp=sharing' # The shareable link

fluff29, id29 = link29.split('d/')
id29 = id29[0:33]
print (id29) # Verify that you have everything after 'd/'

downloaded29 = drive.CreateFile({'id':id29}) 
downloaded29.GetContentFile('Filename.csv')  
divvy_trips_2014_q1q2 = pd.read_csv('Filename.csv')
# Dataset is now stored in a Pandas Dataframe
# Out:
# 1SncXLKgidPPN_f4RYnpnd5e2zujbnOI5

# %%
divvy_2014 = [divvy_trips_2014_q4,divvy_trips_2014_0809,divvy_trips_2014_07,divvy_trips_2014_q1q2]

# %%
divvy_trips_2014 = pd.concat(divvy_2014, axis=0)

# %%
# Rename 2014 columns to match future years
divvy_trips_2014 = divvy_trips_2014.rename(columns = {'starttime':'start_time','stoptime':'end_time'})

# %%
divvy_trips_2014 = divvy_trips_2014.sort_values(by='start_time')

# %%
divvy_trips_2014['start_time'] = divvy_trips_2014['start_time'].apply(lambda x: x+':00' if len(x) <= 16 else x)
divvy_trips_2014['end_time'] = divvy_trips_2014['end_time'].apply(lambda x: x+':00' if len(x) <= 16 else x)

# %%
divvy_trips_2014['start_time'] = pd.to_datetime(divvy_trips_2014['start_time'], format = '%m/%d/%Y  %H:%M:%S')
divvy_trips_2014['end_time'] = pd.to_datetime(divvy_trips_2014['end_time'], format = '%m/%d/%Y  %H:%M:%S')

# %% [markdown]
# ### 2013 Divvy Rideshare Datasets

# %%
# 2013 

link30 = 'https://drive.google.com/file/d/1q-v8Y069e1u_lTitkanNUcb3Hscq3KSD/view?usp=sharing' # The shareable link

fluff30, id30 = link30.split('d/')
id30 = id30[0:33]
print (id30) # Verify that you have everything after 'd/'

downloaded30 = drive.CreateFile({'id':id30}) 
downloaded30.GetContentFile('Filename.csv')  
divvy_trips_2013 = pd.read_csv('Filename.csv')
# Dataset is now stored in a Pandas Dataframe
# Out:
# 1q-v8Y069e1u_lTitkanNUcb3Hscq3KSD
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# Rename 2013 columns to match future years
divvy_trips_2013 = divvy_trips_2013.rename(columns = {'starttime':'start_time','stoptime':'end_time'})

# %%
divvy_trips_2013 = divvy_trips_2013.sort_values(by='start_time')

# %%
divvy_trips_2013['start_time'] = divvy_trips_2013['start_time'].apply(lambda x: x+':00' if len(x) <= 16 else x)
divvy_trips_2013['end_time'] = divvy_trips_2013['end_time'].apply(lambda x: x+':00' if len(x) <= 16 else x)

# %%
divvy_trips_2013['start_time'] = pd.to_datetime(divvy_trips_2013['start_time'], format = '%Y-%m-%d  %H:%M:%S')
divvy_trips_2013['end_time'] = pd.to_datetime(divvy_trips_2013['end_time'], format = '%Y-%m-%d  %H:%M:%S')

# %% [markdown]
# ### Merge years 2013-2018

# %%
divvy_years_13_18 = [divvy_trips_2018,divvy_trips_2017,divvy_trips_2016,divvy_trips_2015,divvy_trips_2014,divvy_trips_2013]

# %%
divvy_trips = pd.concat(divvy_years_13_18, axis=0)

# %%
divvy_trips = divvy_trips.sort_values(by='start_time')

# %%
divvy_trips = divvy_trips.drop(columns=['birthday','birthyear','gender'])

# %%
# Saving dataframe to CSV in My Drive 
divvy_trips.to_csv('/drive/My Drive/Divvy/divvy_trips.csv', index=False)

# %%
divvy_trips.head()
# Out:
#         trip_id          start_time  ...             to_station_name    usertype
# 356742     3940 2013-06-27 01:06:00  ...  Larrabee St & Kingsbury St  Subscriber
# 356744     4113 2013-06-27 11:09:00  ...        May St & Randolph St  Subscriber
# 356745     4119 2013-06-27 11:12:00  ...        May St & Randolph St  Subscriber
# 356746     4134 2013-06-27 11:24:00  ...     Wood St & Milwaukee Ave  Subscriber
# 356747     4162 2013-06-27 11:39:00  ...   Cannon Dr & Fullerton Ave  Subscriber
#
# [5 rows x 10 columns]

# %% [markdown]
# #### Divvy Bike Stations

# %%
link31 = 'https://drive.google.com/file/d/10y-uN2woSij2gILl7HUHjXgL1tamugaY/view?usp=sharing' # The shareable link

fluff31, id31 = link31.split('d/')
id31 = id31[0:33]
print (id31) # Verify that you have everything after 'd/'

downloaded31 = drive.CreateFile({'id':id31}) 
downloaded31.GetContentFile('Filename.csv')  
divvy_stations = pd.read_csv('Filename.csv')
# Dataset is now stored in a Pandas Dataframe

# %%
divvy_stations = divvy_stations.rename(columns = {'ID':'id', 
                                                  'Station Name':'station_name', 
                                                  'Total Docks':'total_docks', 
                                                  'Docks in Service':'docks_in_service', 
                                                  'Status':'status',
                                                  'Latitude':'latitude',
                                                  'Longitude':'longitude', 
                                                  'Location':'location'})

# %%
divvy_stations_locations = divvy_stations[['id','location']]

# %%
divvy_stations_locations

# %%
link32 = 'https://drive.google.com/file/d/1x4x0KmjuOVbO_cg6WM58pTOedCsERWvP/view?usp=sharing' # The shareable link

fluff32, id32 = link32.split('d/')
id32 = id32[0:33]
print (id32) # Verify that you have everything after 'd/'

downloaded32 = drive.CreateFile({'id':id32}) 
downloaded32.GetContentFile('Filename.csv')  
divvy_trips = pd.read_csv('Filename.csv')
# Dataset is now stored in a Pandas Dataframe

# %% [markdown]
# ### Merge Bike Station Data

# %%
result = pd.merge(divvy_trips,
                  divvy_stations_locations, 
                  how='left',
                  left_on='from_station_id',
                  right_on='id')
result.head()

# %%
result1 = pd.merge(divvy_trips,
                  divvy_stations_locations, 
                  how='left',
                  left_on='to_station_id',
                  right_on='id')
result1.head()

# %%
result2 = pd.merge(result,
                  result1, 
                  how='left',
                  on='trip_id')
result2.head()

# %%
result2 = result2.drop(columns=['start_time_y','end_time_y','bikeid_y','tripduration_y','from_station_id_y','from_station_name_y','to_station_id_y','to_station_name_y','usertype_y','id_x','id_y'], axis=1)

# %%
result2 = result2.rename(columns = {'start_time_x':'start_time', 
                                    'end_time_x':'end_time', 
                                    'bikeid_x':'bikeid', 
                                    'tripduration_x':'tripduration',
                                    'from_station_id_x':'from_station_id', 
                                    'from_station_name_x':'from_station_name', 
                                    'to_station_id_x':'to_station_id',
                                    'to_station_name_x':'to_station_name', 
                                    'usertype_x':'usertype',  
                                    'location_x':'from_station_location', 
                                    'location_y':'to_station_location'})

# %%
result2.head()

# %%
divvy = result2

# %%
divvy.to_csv('/drive/My Drive/Divvy/divvy.csv', index=False)
